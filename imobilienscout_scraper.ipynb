# %%
import re
import time
import logging

logging.info = print

import numpy as np
import pandas as pd
from urllib.parse import urlencode
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import Select

# %%
class Immobilienscout24Scraper():
    def __init__(self, path_to_chromedriver: str = '', headless: bool = True, sleep_time: float = 1):
        """
        Parameters
        ----------
        path_to_chromedriver: str 
            Path to executable of chromedriver
        headless: bool
            Browser headles
        sleep_time: float
            Sleep time in seconds between requests
        """
        self.BASE_URL = 'https://www.immobilienscout24.at/'
        self.AVAILABLE_OPTIONS = ['BUY','RENT', 'TEMPORARY_RENT']
        self.PATH_TO_CHROMEDRIVER = path_to_chromedriver
        self.HEADLESS = headless
        self.SLEEP_TIME = sleep_time
    
    def _accept_cookies(self,browser: webdriver):
        """
        Accept cookies if form pops up
        """
        try:
            root = browser.find_element_by_id('usercentrics-root')
            if 'Alle akzeptieren' in root.text:
                ac = ActionChains(browser)
                ac.move_to_element(root)\
                  .pause(self.SLEEP_TIME)\
                  .click()\
                  .perform()
                for i in range(7):
                    ac.send_keys(Keys.TAB).perform()
                ac.send_keys(Keys.ENTER).perform()
        except:
            pass
        
    def _search(self, browser: webdriver, location: str, offer_type: str = 'BUY'):
        """
        Write location and offer_type into the search fields and click search button

        Parameters
        ----------
        browser: webdriver 
            Instance of webdriver
        offer_type: str
            Wanted offer type
        locacation: str
            Wanted location
        """
        location_element = browser.find_element_by_id('downshift-0-input')
        location_element.clear()
        location_element.send_keys(location)
        location_element.send_keys(Keys.ENTER)

        select_element = Select(browser.find_element_by_class_name('pT3G8'))
        select_element.select_by_value(offer_type)
        
        button = browser.find_element_by_class_name('aZs4H').click()
        time.sleep(self.SLEEP_TIME)
        
    def _load_url(self, browser: webdriver, url: str, max_retries: int = 1) -> None:
        """
        Load url

        Parameters
        ----------
        browser: webdriver 
            Instance of webdriver
            
        url: str 
            Url to load
            
        max_retries: int
            How many retries is possible
        """
        logging.info(f'Loading: {url}')
        
        sleep_time = self.SLEEP_TIME
        retries = 1
        while True:
            try:
                browser.get(url)
                break
            except:
                if retry == max_retries:
                    raise
                else:
                    sleep_time *= 2
                    retries += 1
                    time.sleep(sleep_time)
                           
        time.sleep(self.SLEEP_TIME)
        browser.maximize_window()
    
    def _init_browser(self) -> webdriver:
        """
        Initialize browser

        Returns
        -------
        set
            webdriver
        """
        chrome_options = Options()
        chrome_options.add_argument("--disable-popup-blocking")
        chrome_options.add_argument("--incognito")
        chrome_options.add_argument("--start-maximized")
        chrome_options.add_argument('--no-sandbox')
        chrome_options.add_argument('--disable-dev-shm-usage')
        
        if self.HEADLESS:
            chrome_options.add_argument("--headless")
        
        if self.PATH_TO_CHROMEDRIVER == '':
            return webdriver.Chrome(options=chrome_options)
  
        return webdriver.Chrome(self.PATH_TO_CHROMEDRIVER, options=chrome_options)

    def _get_adverts_v1(self, browser) -> list:
        """
        Gets the data from adverts version 1
        
        Parameters
        ----------
        browser: webdriver 
            Instance of webdriver
        """
        adverts = browser.find_elements_by_class_name('WgMl2')
                
        new_data = []
        for advert in adverts:
            self._accept_cookies(browser)
            new_data.append(
                {
                    'url': advert.find_element_by_class_name('Skhfr').get_attribute('href') if advert.find_elements_by_class_name('Skhfr') else np.nan,
                    'title': advert.find_element_by_class_name('YOneO').text.strip() if advert.find_elements_by_class_name('YOneO') else np.nan,
                    'location': advert.find_element_by_class_name('gOIzK').text.strip() if advert.find_elements_by_class_name('gOIzK') else np.nan,
                    'rooms_text': advert.find_elements_by_class_name('TGYEW')[0].text.strip().replace('\n',' ') if advert.find_elements_by_class_name('TGYEW') else np.nan,
                    'area_text':  advert.find_elements_by_class_name('TGYEW')[1].text.strip().replace('\n',' ') if len(advert.find_elements_by_class_name('TGYEW')) > 1 else np.nan,
                    'price_text': advert.find_element_by_class_name('spDjI').text.strip() if advert.find_elements_by_class_name('spDjI') else np.nan,
                    'contact': advert.find_element_by_class_name('OA93m').text.strip().replace('\n',' ') if advert.find_elements_by_class_name('OA93m') else np.nan

                }
            )
        return new_data
    
    def _get_adverts_v2(self, browser):
        """
        Gets the data from adverts version 2
        
        Parameters
        ----------
        browser: webdriver 
            Instance of webdriver
        """
        adverts = browser.find_elements_by_class_name('eTh4Y')
                
        new_data = []
        for advert in adverts:
            self._accept_cookies(browser)
            new_data.append(
                {
                    'url': advert.find_element_by_class_name('NCjTr').get_attribute('href') if advert.find_elements_by_class_name('NCjTr') else np.nan,
                    'title': advert.find_element_by_class_name('NCjTr').text.strip() if advert.find_elements_by_class_name('NCjTr') else np.nan,
                    'location': advert.find_element_by_class_name('u2szU').text.strip() if advert.find_elements_by_class_name('u2szU') else np.nan,
                    'rooms_text': advert.find_elements_by_class_name('TGYEW')[0].text.strip().replace('\n',' ') if advert.find_elements_by_class_name('TGYEW') else np.nan,
                     'area_text':  advert.find_elements_by_class_name('TGYEW')[1].text.strip().replace('\n',' ') if len(advert.find_elements_by_class_name('TGYEW')) > 1 else np.nan,
                    'price_text': advert.find_element_by_class_name('spDjI').text.strip() if advert.find_elements_by_class_name('spDjI') else np.nan,
                    'contact': advert.find_element_by_class_name('OA93m').text.strip().replace('\n',' ') if advert.find_elements_by_class_name('OA93m') else np.nan
                }
            )
            
        return new_data

    def scrape_adverts(self, location: str, offer_type: str, page_limit: int = 10):
        """
        Scrape adverts for required location and offer type
        
        Parameters
        ----------
        offer_type: str
            Wanted offer type
        locacation: str
            Wanted location
        page_limit: int
            How many page to scrape
        """
        if offer_type not in self.AVAILABLE_OPTIONS:
            raise Exception(f'Offer type {offer_type} not supported! Please choose one from: BUY,RENT,TEMPORARY_RENT')
            
        data = []
        with self._init_browser() as browser:
            self._load_url(browser, self.BASE_URL)
            self._accept_cookies(browser)
            self._search(browser, location, offer_type)
            self._accept_cookies(browser)
            
            search_url = browser.current_url
            page_num = 1
            while True:
                new_data = (
                    self._get_adverts_v1(browser)
                  + self._get_adverts_v2(browser)
                )
                
                if not new_data or page_limit <= page_num:
                    break
                
                data += new_data
                page_num += 1
                new_url = search_url + f'/seite-{page_num}'
                
                self._load_url(browser, new_url)
                
                
        if data:
            df = pd.DataFrame(data)
            df['offer_type'] = offer_type
            return df
        
        return pd.DataFrame()

# %%
scraper = Immobilienscout24Scraper(headless=False, sleep_time=5)

# %%
scraper.AVAILABLE_OPTIONS
# Out:
# ['BUY', 'RENT', 'TEMPORARY_RENT']

# %%
to_scrape = [
    ('Wien','BUY', 11),
    ('Wien','RENT', 11)
]

# %%
data = []
for combination in to_scrape:
    data.append(scraper.scrape_adverts(*combination))
# Out:
# Loading: https://www.immobilienscout24.at/
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-2
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-3
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-4
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-5
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-6
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-7
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-8
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-9
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-10
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-kaufen/seite-11
# Loading: https://www.immobilienscout24.at/
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-2
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-3
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-4
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-5
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-6
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-7
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-8
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-9
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-10
# Loading: https://www.immobilienscout24.at/regional/wien/wien/wohnung-mieten/seite-11

# %%
df_scraped = pd.concat(data)

# %%
df_scraped.head()
# Out:
#                                                  url  \
# 0  https://www.immobilienscout24.at/expose/613b30...
# 1  https://www.immobilienscout24.at/expose/6319f8...
# 2  https://www.immobilienscout24.at/expose/627249...
# 3  https://www.immobilienscout24.at/expose/627379...
# 4  https://www.immobilienscout24.at/expose/627248...
#
#                                                title  \
# 0                                            Lemonie
# 1    AM MÜHLWASSER - Lobaugasse 116 - PROVISIONSFREI
# 2  PARK & BLOOM - Exklusives Neubauprojekt am Ran...
# 3      Garten–Städtchen–22 - Wohnen am Fliedergarten
# 4  Purer Wohntraum im 15.Bezirk! Exklusive, perfe...
#
#                              location    rooms_text                 area_text  \
# 0  Albrechtskreithgasse 32, 1160 Wien  2 – 3 Zimmer   42,41 – 46,04 m² Fläche
# 1                           1220 Wien  2 – 3 Zimmer    49,4 – 105,1 m² Fläche
# 2                           1180 Wien  2 – 4 Zimmer  47,86 – 189,23 m² Fläche
# 3   Marlen-Haushofer-Weg 2, 1220 Wien  3 – 4 Zimmer   78,55 – 92,56 m² Fläche
# 4                           1150 Wien  2 – 3 Zimmer   62,02 – 70,02 m² Fläche
#
#           price_text                                            contact  \
# 0    ab 229.193,39 €                       Mario Häring 3SI Makler GmbH
# 1       ab 299.000 €         Dennis Bernard WOLF & SOHN Immobilien GmbH
# 2  Preis auf Anfrage  Ing. Dominic Lorenz Lorenz Real Construct Immo...
# 3       ab 382.000 €  Mischek Bauträger Service GmbH Mischek Bauträg...
# 4       ab 469.900 €           Ehsan Karimian Immocity Real Estate GmbH
#
#   offer_type
# 0        BUY
# 1        BUY
# 2        BUY
# 3        BUY
# 4        BUY

# %%
locations = [loc for loc in df_scraped['location'].unique().tolist() if loc!= '']

# %%
import requests 

class GeocodingApi:
    def __init__(self, key: str, sleep_time: int = 1):
        self.base_url = 'http://api.positionstack.com/v1/forward'
        self.key = key
        self.sleep_time = sleep_time
        
    def get_geocoding_data(self, locations: list) -> pd.DataFrame:
        """
        Get geocoding data from the locations list
        
        Parameters
        ----------
        locations: list 
            List with all locations to geocode
        """
        data = []
        for location in locations:
            logging.info(f'Getting goecoding data for: {location}')
            params = {
                'access_key': self.key,
                'query': location
            }
            
            r = requests.get(self.base_url, params = params)
            
            if r.status_code != 200:
                logging.info(f'Something went wrong... Status code is:{r.status_code}')
                continue
            
            response = r.json().get('data')
            if response:
                most_confident_result = sorted(response, key=lambda x: x['confidence'], reverse=True)[0]
                most_confident_result['requested_location'] = location
                
                data.append(most_confident_result)
            
            time.sleep(self.sleep_time)
        
        if data:
            return pd.DataFrame(data)
        
        return pd.DataFrame()

# %%
geo_api = GeocodingApi('my_super_secret_key')

# %%
df_geo = geo_api.get_geocoding_data(locations)
# Out:
# Getting goecoding data for: Albrechtskreithgasse 32, 1160 Wien
# Getting goecoding data for: 1220 Wien
# Getting goecoding data for: 1180 Wien
# Getting goecoding data for: Marlen-Haushofer-Weg 2, 1220 Wien
# Getting goecoding data for: 1150 Wien
# Getting goecoding data for: Nordbahnanlage 4, 1210 Wien
# Getting goecoding data for: Langobardenstraße 3, 1220 Wien
# Getting goecoding data for: Schlachthausgasse, 1030 Wien
# Getting goecoding data for: 1030 Wien
# Getting goecoding data for: Einsiedlergasse 27, 1050 Wien
# Getting goecoding data for: Hauptstraße 104, 1140 Wien
# Getting goecoding data for: Donaufelder Straße 205, 1220 Wien
# Getting goecoding data for: Maximilian-Reich-Weg 4, 1210 Wien
# Getting goecoding data for: Attemsgasse 44, 1220 Wien
# Getting goecoding data for: Schweizertalstraße, 1130 Wien
# Getting goecoding data for: Donaufelder Straße 207, 1220 Wien
# Getting goecoding data for: Dißlergasse 8, 1030 Wien
# Getting goecoding data for: Petzvalgasse 4, 1040 Wien
# Getting goecoding data for: 1140 Wien
# Getting goecoding data for: Klederinger Straße 63-65, 1100 Wien,Favoriten
# Getting goecoding data for: 1110 Wien / Simmering
# Getting goecoding data for: 1210 Wien / Wien 21., Floridsdorf
# Getting goecoding data for: Klenaugasse 5, 1220 Wien
# Getting goecoding data for: Zollergasse 31, 1070 Wien
# Getting goecoding data for: Sellingergasse 8, 1110 Wien,Simmering
# Getting goecoding data for: Jedleseer Straße 59, 1210 Wien
# Getting goecoding data for: Martinstraße 41-43, 1180 Wien
# Getting goecoding data for: Linzer Straße 161, 1140 Wien
# Getting goecoding data for: 1130 Wien
# Getting goecoding data for: 1030 Wien,Landstraße
# Getting goecoding data for: Seemüllergasse 10, 1170 Wien
# Getting goecoding data for: 1170 Wien
# Getting goecoding data for: Dr.-Adolf-Schärf-Platz 5, 1220 Wien
# Getting goecoding data for: Auhofstraße 196, 1130 Wien
# Getting goecoding data for: 1230 Wien
# Getting goecoding data for: Gerasdorfer Straße 5, 1210 Wien
# Getting goecoding data for: 1020 Wien
# Getting goecoding data for: 1010 Wien
# Getting goecoding data for: Wehlistraße 291, 1020 Wien
# Getting goecoding data for: Benjowskigasse 3, 1220 Wien
# Getting goecoding data for: 1060 Wien,Mariahilf
# Getting goecoding data for: 1090 Wien
# Getting goecoding data for: Fundergasse 6, 1220 Wien
# Getting goecoding data for: 1010 Wien,Innere Stadt
# Getting goecoding data for: 1210 Wien
# Getting goecoding data for: 1160 Wien
# Getting goecoding data for: Anton-Baumgartner-Straße 19, 1230 Wien
# Getting goecoding data for: 1080 Wien
# Getting goecoding data for: 1190 Wien
# Getting goecoding data for: Heustadelgasse 29-29A, 1220 Wien
# Getting goecoding data for: 1020 Wien,Leopoldstadt
# Getting goecoding data for: 1160 Wien,Ottakring
# Getting goecoding data for: Tamariskengasse 106, 1220 Wien
# Getting goecoding data for: 1220 Wien,Donaustadt
# Getting goecoding data for: Joseph Lister Gasse 56, 1130 Wien
# Getting goecoding data for: Ratschkygasse 31, 1120 Wien
# Getting goecoding data for: 1040 Wien
# Getting goecoding data for: 1100 Wien,Favoriten
# Getting goecoding data for: 1180 Wien,Währing
# Getting goecoding data for: 1190 Wien / Döbling
# Getting goecoding data for: Wagramer Straße 2, 1220 Wien
# Getting goecoding data for: 1100 Wien
# Getting goecoding data for: 1200 Wien
# Getting goecoding data for: 1130 Wien / Hietzing
# Getting goecoding data for: Haberlgasse 31, 1160 Wien
# Getting goecoding data for: 1070 Wien,Neubau
# Getting goecoding data for: Nußdorfer Straße, 1090 Wien
# Getting goecoding data for: Kaschlgasse, 1200 Wien,Brigittenau
# Getting goecoding data for: Wagramer Straße 4, 1220 Wien,Donaustadt
# Getting goecoding data for: Sellingergasse 7, 1110 Wien
# Getting goecoding data for: 1130 Wien,Hietzing
# Getting goecoding data for: 1160 Wien / Wien 16., Ottakring
# Getting goecoding data for: 1010 Wien / Wien 1., Innere Stadt
# Getting goecoding data for: Bernreiterplatz 12, 1210 Wien
# Getting goecoding data for: 1110 Wien
# Getting goecoding data for: Döblerhofstraße 10, 1030 Wien
# Getting goecoding data for: Eileen-Gray-Gasse 2, 1220 Wien
# Getting goecoding data for: 1030 Wien / Wien 3., Landstraße
# Getting goecoding data for: 1230 Wien,Liesing
# Getting goecoding data for: Winkelbreiten, 1130 Wien
# Getting goecoding data for: Lannesstraße 80, 1220 Wien
# Getting goecoding data for: Schweizertalstraße 39, 1130 Wien
# Getting goecoding data for: Edelhofgasse 8, 1180 Wien
# Getting goecoding data for: Drygalskiweg 59, 1210 Wien
# Getting goecoding data for: Argonautenstraße 3, 1220 Wien
# Getting goecoding data for: Mühlhausergasse 5, 1220 Wien
# Getting goecoding data for: Bergheidengasse 21, 1130 Wien
# Getting goecoding data for: Gersthofer Straße 119, 1180 Wien
# Getting goecoding data for: Franz-Josefs-Kai 51, 1010 Wien
# Getting goecoding data for: Armbrustergasse 24A, 1190 Wien
# Getting goecoding data for: Wagramer Straße 113, 1220 Wien
# Getting goecoding data for: Hockegasse, 1180 Wien
# Getting goecoding data for: Glanzinggasse, 1190 Wien
# Getting goecoding data for: Kuchelauer Hafenstraße, 1190 Wien
# Getting goecoding data for: Kuchelauer Hafenstraße 98, 1190 Wien
# Getting goecoding data for: Panethgasse 39, 1220 Wien
# Getting goecoding data for: Börseplatz, 1010 Wien
# Getting goecoding data for: Beatrixgasse, 1030 Wien
# Getting goecoding data for: Gersthofer Straße, 1180 Wien
# Getting goecoding data for: Hovenweg 32, 1220 Wien
# Getting goecoding data for: 1120 Wien
# Getting goecoding data for: Gersthoferstraße, 1180 Wien
# Getting goecoding data for: Leopoldauer Straße, 1210 Wien
# Getting goecoding data for: Leopoldauer Straße 70-72, 1210 Wien
# Getting goecoding data for: Spallartgasse 21-23, 1140 Wien
# Getting goecoding data for: Baranygasse 7, 1220 Wien
# Getting goecoding data for: Dresdner Straße 17-19, 1200 Wien
# Getting goecoding data for: Leopoldauer Straße 131, 1210 Wien
# Getting goecoding data for: Pragerstraße 105, 1210 Wien
# Getting goecoding data for: Wehlistraße 61, 1200 Wien
# Getting goecoding data for: Ullmannstraße 24, 1150 Wien
# Getting goecoding data for: Bertha-von-Suttner-Gasse 10a-12a, 1220 Wien
# Getting goecoding data for: Handelskai 98-100, 1200 Wien
# Getting goecoding data for: Pogrelzstraße, 1220 Wien
# Getting goecoding data for: Wehlistraße 330, 1020 Wien
# Getting goecoding data for: Lavaterstraße 2-4, 1220 Wien
# Getting goecoding data for: Pogrelzstraße 83, 1220 Wien
# Getting goecoding data for: Groß-Enzersdorfer Straße 66-72, 1220 Wien
# Getting goecoding data for: Donau-City-Straße, 1220 Wien
# Getting goecoding data for: Van-der-Nüll-Gasse 45-49, 1100 Wien
# Getting goecoding data for: Stoß im Himmel 3, 1010 Wien
# Getting goecoding data for: Dannebergplatz, 1030 Wien
# Getting goecoding data for: Karl-Popper-Straße 5, 1100 Wien
# Getting goecoding data for: Kleingasse 20, 1030 Wien
# Getting goecoding data for: Buchengasse, 1100 Wien
# Getting goecoding data for: Bertha-von-Suttner-Gasse 10, 1220 Wien
# Getting goecoding data for: Kagraner Platz 26, 1220 Wien
# Getting goecoding data for: Erzherzog-Karl-Straße 107, 1220 Wien
# Getting goecoding data for: Jörgerstraße 4-8, 1180 Wien
# Getting goecoding data for: Leopoldauer Platz 9-11, 1210 Wien
# Getting goecoding data for: Favoritenstraße, 1040 Wien
# Getting goecoding data for: Reisnerstraße, 1030 Wien
# Getting goecoding data for: Karl-Popper-Straße, 1100 Wien
# Getting goecoding data for: Julius Payer Gasse, 1220 Wien
# Getting goecoding data for: Arsenal, 1030 Wien
# Getting goecoding data for: Oswaldgasse, 1120 Wien
# Getting goecoding data for: Wiesenthalgasse 4A, 1100 Wien
# Getting goecoding data for: Aspernstrasse 70, 1220 Wien
# Getting goecoding data for: Geiselbergstraße, 1110 Wien
# Getting goecoding data for: Erdberger Lände "Adl" 38, 1030 Wien
# Getting goecoding data for: Spallartgasse 21, 1140 Wien
# Getting goecoding data for: Spallartgasse 9, 1140 Wien
# Getting goecoding data for: Kärntner Ring, 1010 Wien
# Getting goecoding data for: Lorenz-Mandl-Gasse, 1160 Wien
# Getting goecoding data for: Leonard-Bernstein-Straße 8, 1220 Wien
# Getting goecoding data for: Bloch Bauer Promenade, 1100 Wien
# Getting goecoding data for: Selma-Steinmetz-Gasse, 1210 Wien
# Getting goecoding data for: 1070 Wien
# Getting goecoding data for: 1060 Wien
# Getting goecoding data for: Susi-Nicoletti-Weg, 1100 Wien
# Getting goecoding data for: Raphael-Donner-Allee 6, 1220 Wien
# Getting goecoding data for: 1010 Wien, Innere Stadt
# Getting goecoding data for: 1050 Wien,Margareten
# Getting goecoding data for: 1120 Wien, Meidling
# Getting goecoding data for: Neustiftgasse 96, 1070 Wien
# Getting goecoding data for: Groß-Enzersdorfer Straße, 1220 Wien
# Getting goecoding data for: Wehlistrasse 165, 1020 Wien
# Getting goecoding data for: Flachgasse, 1140 Wien
# Getting goecoding data for: Remystraße 35, 1100 Wien
# Getting goecoding data for: Schweidlgasse 30, 1020 Wien
# Getting goecoding data for: Schererstraße 48, 1210 Wien
# Getting goecoding data for: Bischoffgasse, 1120 Wien
# Getting goecoding data for: Wehlistrasse 291, 1020 Wien
# Getting goecoding data for: Leopold-Böhm-Straße 6, 1030 Wien
# Getting goecoding data for: Wehlistraße 63/stiege 7, 1200 Wien
# Getting goecoding data for: Hegergasse 15, 1030 Wien
# Getting goecoding data for: Erlaaer Straße, 1230 Wien
# Getting goecoding data for: Montevideogasse, 1130 Wien,Hietzing
# Getting goecoding data for: Mariannengasse 22, 1090 Wien
# Getting goecoding data for: 1080 Wien / Wien 8., Josefstadt
# Getting goecoding data for: Ausstellungsstraße, 1020 Wien
# Getting goecoding data for: Breitenseer Straße, 1140 Wien
# Getting goecoding data for: Grossenzersdorferstrasse 74, 1220 Wien
# Getting goecoding data for: Mantlergasse 23, 1130 Wien
# Getting goecoding data for: 1090 Wien / Wien 9., Alsergrund
# Getting goecoding data for: Schnirchgasse 13, 1030 Wien
# Getting goecoding data for: Schweidlgasse 23, 1020 Wien
# Getting goecoding data for: Wagramer Straße, 1220 Wien, Donaustadt
# Getting goecoding data for: Kugelmanngasse, 1230 Wien
# Getting goecoding data for: Schöpfleuthnergasse 11, 1210 Wien
# Getting goecoding data for: Landstraßer Hauptstraße 114, 1030 Wien
# Getting goecoding data for: Attemsgasse 7, 1220 Wien
# Getting goecoding data for: Adolf-Czettel-Gasse, 1160 Wien
# Getting goecoding data for: Petrusgasse, 1030 Wien
# Getting goecoding data for: 1050 Wien
# Getting goecoding data for: Adolf Czettel Gasse 9, 1160 Wien
# Getting goecoding data for: 1190 Wien, Döbling
# Getting goecoding data for: Genochplatz 1, 1220 1220 - Wien
# Getting goecoding data for: Pfefferhofgasse 1A, 1030 Wien
# Getting goecoding data for: Burggasse 112, 1070 Wien
# Getting goecoding data for: Cumberlandstraße 79, 1140 Wien
# Getting goecoding data for: Fleischmarkt 18, 1010 Wien
# Getting goecoding data for: Favoritenstraße, 1100 Wien
# Getting goecoding data for: Diesterweggasse 31, 1140 Wien
# Getting goecoding data for: Staudgasse 75, 1180 Wien
# Getting goecoding data for: 1140 Wien / Wien 14., Penzing
# Getting goecoding data for: Bachgasse, 1160 Wien
# Getting goecoding data for: Urschenböckgasse, 1030 Wien
# Getting goecoding data for: Harmoniegasse, 1090 Wien
# Getting goecoding data for: Holochergasse, 1150 Wien
# Getting goecoding data for: Oberlaaer Straße 225, 1100 Wien
# Getting goecoding data for: Koppstrasse 22, 1160 Wien
# Getting goecoding data for: Guglgasse, 1110 Wien
# Getting goecoding data for: zum weißen Kreuz 10, 1190 Wien
# Getting goecoding data for: Cumberlandstraße 43, 1140 Wien
# Getting goecoding data for: Jheringgasse 17, 1150 Wien
# Getting goecoding data for: Spallartgasse, 1140 Wien

# %%
df_final = df_scraped.merge(df_geo, left_on='location', right_on='requested_location', how='left')

# %%
df_final.head()
# Out:
#                                                  url  \
# 0  https://www.immobilienscout24.at/expose/613b30...
# 1  https://www.immobilienscout24.at/expose/6319f8...
# 2  https://www.immobilienscout24.at/expose/627249...
# 3  https://www.immobilienscout24.at/expose/627379...
# 4  https://www.immobilienscout24.at/expose/627248...
#
#                                                title  \
# 0                                            Lemonie
# 1    AM MÜHLWASSER - Lobaugasse 116 - PROVISIONSFREI
# 2  PARK & BLOOM - Exklusives Neubauprojekt am Ran...
# 3      Garten–Städtchen–22 - Wohnen am Fliedergarten
# 4  Purer Wohntraum im 15.Bezirk! Exklusive, perfe...
#
#                              location    rooms_text                 area_text  \
# 0  Albrechtskreithgasse 32, 1160 Wien  2 – 3 Zimmer   42,41 – 46,04 m² Fläche
# 1                           1220 Wien  2 – 3 Zimmer    49,4 – 105,1 m² Fläche
# 2                           1180 Wien  2 – 4 Zimmer  47,86 – 189,23 m² Fläche
# 3   Marlen-Haushofer-Weg 2, 1220 Wien  3 – 4 Zimmer   78,55 – 92,56 m² Fläche
# 4                           1150 Wien  2 – 3 Zimmer   62,02 – 70,02 m² Fläche
#
#           price_text                                            contact  \
# 0    ab 229.193,39 €                       Mario Häring 3SI Makler GmbH
# 1       ab 299.000 €         Dennis Bernard WOLF & SOHN Immobilien GmbH
# 2  Preis auf Anfrage  Ing. Dominic Lorenz Lorenz Real Construct Immo...
# 3       ab 382.000 €  Mischek Bauträger Service GmbH Mischek Bauträg...
# 4       ab 469.900 €           Ehsan Karimian Immocity Real Estate GmbH
#
#   offer_type   latitude  longitude  ... region_code county locality  \
# 0        BUY  48.220629  16.316295  ...          WI   None   Vienna
# 1        BUY  48.198674  16.348388  ...          WI   None   Vienna
# 2        BUY  48.198674  16.348388  ...          WI   None   Vienna
# 3        BUY  48.198674  16.348388  ...          WI   None   Vienna
# 4        BUY  48.198674  16.348388  ...          WI   None   Vienna
#
#   administrative_area neighbourhood  country country_code continent  \
# 0                Wien      Dornbach  Austria          AUT    Europe
# 1                Wien          None  Austria          AUT    Europe
# 2                Wien          None  Austria          AUT    Europe
# 3                Wien          None  Austria          AUT    Europe
# 4                Wien          None  Austria          AUT    Europe
#
#                                           label  \
# 0  Albrechtskreithgasse 32, Vienna, WI, Austria
# 1                           Vienna, WI, Austria
# 2                           Vienna, WI, Austria
# 3                           Vienna, WI, Austria
# 4                           Vienna, WI, Austria
#
#                    requested_location
# 0  Albrechtskreithgasse 32, 1160 Wien
# 1                           1220 Wien
# 2                           1180 Wien
# 3   Marlen-Haushofer-Weg 2, 1220 Wien
# 4                           1150 Wien
#
# [5 rows x 27 columns]

# %%
df_final.to_excel('immobilienscout_scraped.xlsx', index=False)
